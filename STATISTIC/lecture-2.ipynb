# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import pylab
import math
import sympy

from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter
from scipy.misc import derivative, electrocardiogram
from scipy.optimize import minimize, approx_fprime, fmin, brute
from scipy.signal import find_peaks

# %matplotlib inline

# %% [markdown]
# # Функции

# %% [markdown]
# Построим функцию $$f(x)=\frac{1}{1-x}$$

# %%
x = np.linspace(-3.0, 3.0, 1000) #область определний
y = np.array([1/(1-x_i) for x_i in x]) # область значений
plt.plot(x, y)
plt.show()
# Out:
# /home/orange/venv/lib/python3.6/site-packages/ipykernel_launcher.py:2: RuntimeWarning: divide by zero encountered in double_scalars

# %% [markdown]
# Какова область определения? Какова область значения?

# %% [markdown]
# Построим функцию $$f(x)=2^{x}$$

# %%
x = np.linspace(-100.0, 100.0, 1000)
y = np.array([math.pow(2, x_i) for x_i in x])
plt.plot(x, y)
plt.show()

# %% [markdown]
# # Способы представления функций

# %% [markdown]
# **Программный способ представления.**
#
# Дана функция: ![alt text](https://pp.userapi.com/c854520/v854520891/aaadd/f5M6W-fRFjg.jpg). Напишем для неё код.

# %%
def func(x):
    stepen = 1/4*math.pow(x, 5) - math.pow(x, 4) + 1/4*math.pow(x, 3) + 3/2*math.pow(x, 2) +1
    y = 1 - pow(2, stepen)
    return y

# %% [markdown]
# **Графический способ представления функции.**

# %% [markdown]
# Нарисуем график написанной функции:

# %%
# создаем вектор x
x1 = np.linspace(-3.0, 3.0, 100)
# на основе вектора x строим значения для вектора y
y1 = [func(x1[i]) for i in range(len(x1))]

plt.plot(x1, y1)
plt.title('График функции')
plt.ylabel('y')
plt.xlabel('x')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-81f01aa68d86> in <module>
#       1 # создаем вектор x
# ----> 2 x1 = np.linspace(-3.0, 3.0, 100)
#       3 # на основе вектора x строим значения для вектора y
#       4 y1 = [func(x1[i]) for i in range(len(x1))]
#       5
#
# NameError: name 'np' is not defined

# %% [markdown]
# **Представление функции ввиде формулы.**

# %% [markdown]
# Иногда удобно представить функцию ввиде нескольких формул вместо одной. Например, функция y=abs(x). Если мы хотим записать алгоритм функции, легче всего разделить пространство аргументов на плоскости на 2 отрезка: от $-\infty$ до 0 включительно и от 0 до $+\infty $

# %% [markdown]
# ![alt text](https://pp.userapi.com/c858028/v858028826/2c07f/SOjKZptkdXU.jpg)

# %% [markdown]
# # Полиномиальные функции или многочлены.

# %% [markdown]
# Целая рациональная функция (также полиномиальная функция) — числовая функция одного действительного переменного вида:
# $$f(x) = a_{n}x^{n}+a_{n-1}x^{n-1}+...+a_{2}x^{2}+a_{1}x+a_{0}=\sum_{i=0}^{n}a_{i}x^{i}$$,
# где $n\in \mathbb{N}, a_{n},a_{n-1},...,a_{2},a_{1},a_{0}\in \mathbb{R}, a_{n}\neq 0$

# %% [markdown]
# **Пример построения полинома: степень = 0.**

# %% [markdown]
# коэффициент a = 3

# %%
x1 = np.linspace(-3.0, 3.0, 100)
y1 = [3 for _ in range(len(x1))]
plt.plot(x1, y1, '-o')
plt.title('График функции')
plt.ylabel('y')
plt.xlabel('x')

plt.show()

# %% [markdown]
# **Пример построения полинома степени 2: подбрасывание мяча**

# %%
def polynom_2(x):
    y = -4.9*x*x + 6.1*x + 1.4
    return y

x1 = np.linspace(-0.25, 1.5, 100)
y1 = [polynom_2(x1[i]) for i in range(len(x1))]
plt.plot(x1, y1, '-o')
plt.title('График функции полинома степени 2: траектория мяча')
plt.ylabel('y')
plt.xlabel('x')

plt.show()

# %% [markdown]
# **Пример построения полинома степени 2: Golden Gate в Сан-Франсиско**

# %%
def polynom_golden_gate(x):
    y = 0.00037*x*x - 0.475*x + 230
    return y

x1 = np.linspace(-1000, 2300, 100)
y1 = [polynom_golden_gate(x1[i]) for i in range(len(x1))]
plt.figure(figsize=(20,4))
plt.plot(x1, y1, '-o')
plt.title('График функции полинома степени 2: Golden Gate в Сан-Франсиско')
plt.ylabel('y')
plt.xlabel('x')

plt.show()

# %% [markdown]
# # Предел

# %%
x = np.array([i for i in range(-1000, 1000)])
y = np.array([math.sin(math.radians(x_i))/x_i for x_i in x])
plt.plot(x, y)
plt.show()
# Out:
# /home/orange/venv/lib/python3.6/site-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in true_divide

# %% [markdown]
# Вычислим значение предела функции в точке x = 0

# %%
x = sympy.symbols('x') 
expr = sympy.sin(x)/x; 
    
print("Expression : {}".format(expr))  
      
# Use sympy.limit() method  
limit_expr = sympy.limit(expr, x, 0)   
      
print("Limit of the expression tends to 0 : {}".format(limit_expr))
# Out:
# Expression : sin(x)/x
# Limit of the expression tends to 0 : 1

# %% [markdown]
# # Примеры пределов

# %% [markdown]
# **Пример 1**

# %% [markdown]
# Построим график функции $$f(x)=(1+x)^{\frac{1}{x}}$$

# %%
x = np.linspace(-100, 100, 1000)
y = np.array([(1+x_i)**(1/x_i) for x_i in x])

plt.plot(x, y)
plt.show()
# Out:
# /home/orange/venv/lib/python3.6/site-packages/ipykernel_launcher.py:2: RuntimeWarning: invalid value encountered in double_scalars

# %% [markdown]
# При x->0 значение функции не известно

# %%
print((1+0)**(1/0))
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-107-b0dda14ede2a> in <module>
# ----> 1 print((1+0)**(1/0))
#
# ZeroDivisionError: division by zero

# %% [markdown]
# Если мы рассмотрим значение функции при x->0+, то значение функции будет стремиться к 2,718 (это число является экспонентой)

# %% [markdown]
# x = 0.0001

# %%
print((1+0.0001)**(1/0.0001))
# Out:
# 2.7181459268249255

# %% [markdown]
# x = 0.0000001

# %%
print((1+0.0000001)**(1/0.0000001))
# Out:
# 2.7182816941320818

# %% [markdown]
# Если мы рассмотрим предел слевам (когда x->0-), то значение функции будет стремиться к числу 2,718

# %%
print((1-0.0000001)**(1/-0.0000001))
# Out:
# 2.7182819629423656

# %% [markdown]
# Предел в точке x = 0 стремится к константе exp = 2.718

# %%
print(math.exp(1))
# Out:
# 2.718281828459045

# %% [markdown]
# **Предел 2**

# %% [markdown]
# Построим функцию $$f(x)=1/x$$

# %% [markdown]
# Функция неограниченно растет при приближении к x->0

# %%
x = np.linspace(-100, 100, 1999)
y = np.array([1/x_i for x_i in x])

plt.plot(x, y)
plt.show()
# Out:
# /home/orange/venv/lib/python3.6/site-packages/ipykernel_launcher.py:2: RuntimeWarning: divide by zero encountered in double_scalars

# %% [markdown]
# # Исследование функции с помощью производных

# %% [markdown]
# **Сгенерированный пример**

# %% [markdown]
# Посмотрим данные, сгенерированные с помощью уравнения синуса

# %%
x = np.array([i for i in range(-1000, 1000)])
y = np.array([math.sin(math.radians(x_i)) for x_i in x])
plt.plot(x, y)

# %% [markdown]
# Первая производная

# %%
list_der_sin = []
for i in range(len(x)-1):
    list_der_sin.append((y[i+1]-y[i])/(x[i+1]-x[i]))
list_der_sin.append(list_der_sin[-1])

# %%
fig, axs = plt.subplots(2,figsize=(20,10))
axs[0].set_title('Исходная: sin(x)')
axs[0].plot(x, y)
axs[1].set_title('Первая производная функции: sin`(x) = cos(x)')
axs[1].plot(x, list_der_sin)
axs[1].plot(x, [0 for i in range(len(list_der_sin))], '-')

# %% [markdown]
# Вторая производная

# %%
list_second_der_sin = []
for i in range(len(x)-1):
    list_second_der_sin.append((list_der_sin[i+1]-list_der_sin[i])/(x[i+1]-x[i]))
list_second_der_sin.append(list_second_der_sin[-1])

# %%
fig, axs = plt.subplots(3,figsize=(20,10))
axs[0].set_title('Исходная: sin(x)')
axs[0].plot(x, y)
axs[1].set_title('Первая производная функции: sin`(x) = cos(x)')
axs[1].plot(x, list_der_sin)
axs[1].plot(x, [0 for i in range(len(list_der_sin))], '-')
axs[2].set_title('Вторая производная функции: cos`(x) = -sin(x)')
axs[2].plot(x, list_second_der_sin)
axs[2].plot(x, [0 for i in range(len(list_der_sin))], '-')

# %% [markdown]
# **Реальный пример**

# %% [markdown]
# Рассмотрим график подъема человека по стене. Нам нужно определить, когда человек спустился с верхней точки.

# %%
data = pd.read_csv('data/video.csv')
data.head()
# Out:
#    sec   x1    y1    x2    y2  height
# 0    0  875  1411  1008  1835     414
# 1    1  883  1377  1057  1873     417
# 2    2  862  1397  1066  1872     417
# 3    3  878  1394  1046  1875     417
# 4    4  910  1378  1070  1866     417

# %%
plt.figure(figsize=(20,4))
plt.plot(data.height)
plt.xlabel('время')
plt.ylabel('изменение высоты по времени')
# Out:
# Text(0, 0.5, 'изменение высоты по времени')

# %% [markdown]
# Как найти точку подъема и точку спуска?

# %% [markdown]
# Построим график производной

# %%
list_ids = data.sec.unique()
list_derivatives = []
for i in range(len(list_ids)-1):
    sec_id_next = list_ids[i+1]
    sec_id = list_ids[i]
    height = list(data.loc[data.sec==sec_id, 'height'])[0]
    next_height = list(data.loc[data.sec==sec_id_next, 'height'])[0]
    list_derivatives.append((next_height - height)/(sec_id_next - sec_id))
list_derivatives.append(list_derivatives[-1])
data['first_derivative'] = list_derivatives

# %% [markdown]
# Построим график второй производной

# %%
list_ids = data.sec.unique()
second_list_derivatives = []
for i in range(len(list_ids)-1):
    sec_id_next = list_ids[i+1]
    sec_id = list_ids[i]
    derivative = list(data.loc[data.sec==sec_id, 'first_derivative'])[0]
    next_derivative = list(data.loc[data.sec==sec_id_next, 'first_derivative'])[0]
    if (next_height - height) == 0:
        second_list_derivatives.append(-10)    
    else:
        second_list_derivatives.append((next_derivative - derivative)/(sec_id_next - sec_id))
second_list_derivatives.append(second_list_derivatives[-1])
data['second_derivative'] = second_list_derivatives

# %%
fig, axs = plt.subplots(3,figsize=(20,10))
axs[0].set_title('Исходная')
axs[0].plot([i for i in range(0, len(data))], data.height)
axs[1].set_title('Первая производная функции')
axs[1].plot([i for i in range(0, len(data['first_derivative']))], data['first_derivative'])
axs[2].set_title('Вторая производная функции')
axs[2].plot([i for i in range(0, len(data['second_derivative']))], data['second_derivative'])

# %% [markdown]
# Построим график изменения высоты для одного пролаза

# %%
fig, axs = plt.subplots(3,figsize=(20,10))
axs[0].set_title('Исходная')
axs[0].plot([i for i in range(0, 200)], data.height[:200])
axs[1].set_title('Первая производная функции')
axs[1].plot([i for i in range(0, 200)], data['first_derivative'][:200])
axs[1].plot([i for i in range(200)], [0 for i in range(200)], '-')
axs[2].set_title('Вторая производная функции')
axs[2].plot([i for i in range(0, 200)], data['second_derivative'][:200])
axs[2].plot([i for i in range(200)], [0 for i in range(200)], '-')

# %% [markdown]
# Найдем точку топа (когда человек достиг самой высокой точки) с помощью команды **find_peaks** и атрибутов **prominence** и **width**:
#
# **prominence**: The prominence of a peak measures how much a peak stands out from the surrounding baseline of the signal and is defined as the vertical distance between the peak and its lowest contour line.

# %% [markdown]
# **width**: Required width of peaks in samples. Either a number, None, an array matching x or a 2-element sequence of the former. The first element is always interpreted as the minimal and the second, if supplied, as the maximal required width.

# %% [markdown]
# Команда find_peaks: https://docs.scipy.org/doc/scipy/reference/generated/scipy.signal.find_peaks.html

# %%
peaks, _ = find_peaks(data.height, prominence=1, width=20)
plt.plot(data.height)
plt.plot(peaks, data.height[peaks], "x")
plt.show()

# %% [markdown]
# ### Поиск экстремумов

# %%
def f(x):
    return -1 * np.sin(x)/x

# %%
def f_(x):
    return -f(x)

# %% [markdown]
# ### Поиск локальных минимумов

# %%
# objective function

x0 = -5 # start from x = -5
xmin0 = fmin(f,x0)

x1 = -4 # start from x = -4
xmin1 = fmin(f,x1)

# plot the function
x = np.linspace(-15,15,100)
y = f(x)
pylab.plot(x,y)
# plot of x0 and the minimum found startin from x0
pylab.plot(x0, f(x0), 'bd', xmin0, f(xmin0), 'bo')
# plot of x1 and the minimum found startin from x1
pylab.plot(x1, f(x1), 'rd', xmin1, f(xmin1), 'ro')

pylab.axis([-15,15,-1.3,0.3])
pylab.show()
# Out:
# Optimization terminated successfully.
#          Current function value: -0.128375
#          Iterations: 18
#          Function evaluations: 36
# Optimization terminated successfully.
#          Current function value: -1.000000
#          Iterations: 19
#          Function evaluations: 38

# %% [markdown]
# ### Поиск локальных максимумов

# %%
# objective function

x0 = 10 # start from x = -5
xmin0 = fmin(f_,x0)

x1 = -4 # start from x = -4
xmin1 = fmin(f_, x1)

# plot the function
x = np.linspace(-15,15,100)
y = f(x)
pylab.plot(x,y)
# plot of x0 and the minimum found startin from x0
pylab.plot(x0, f(x0), 'bd', xmin0, f(xmin0), 'bo')
# plot of x1 and the minimum found startin from x1
pylab.plot(x1, f(x1), 'rd', xmin1, f(xmin1), 'ro')

pylab.axis([-15,15,-1.3,0.3])
pylab.show()
# Out:
# Optimization terminated successfully.
#          Current function value: -0.091325
#          Iterations: 15
#          Function evaluations: 30
# Optimization terminated successfully.
#          Current function value: -0.217234
#          Iterations: 13
#          Function evaluations: 26

# %%
f_(xmin0)
# Out:
# array([-0.0913252])

# %% [markdown]
# ### Производная

# %%
from scipy.misc import derivative
def f(x):
    return x**3 + x**2
derivative(f, 1.0, dx=1e-6)
# Out:
# 4.999999999921734

# %% [markdown]
# derivative(f, 1.0, dx=1e-6):
# *   given a function, use a central difference formula with spacing dx to compute the n-th derivative at x0.
# *   1.0 - the point at which n-th derivative is found
# *   dx - spacing

# %%
def f(x):
    return x ** 2 + 1

# %%
x = np.linspace(-10, 10)
fx = f(x)
f1x = [derivative(f, xx, dx=1e-6, n=1) for xx in x]

# %%
fig, axs = plt.subplots(2,figsize=(10,10))
axs[0].set_title('Исходная')
axs[0].plot(x, fx, label='function')
axs[1].set_title('Первая производная функции')
axs[1].plot(x, f1x, label='derivative')

# %% [markdown]
# ### Вычисление частных производных

# %% [markdown]
# Хотим посчитать частные производные функции $f(x,y)=x^3y-x^2y^2+x-1$ в точке (1, 1)
#
# $f'_x=3x^2y-2xy^2+1$
#
# $f'_y=x^3-2x^2y$
#
# $f'_x(1,1)=3-2+1=2$
#
# $f'_y(1,1)=1-2=-1$
#
# $grad_f(1,1) = (2, -1)$

# %% [markdown]
# # Пример оптимизационной задачи

# %%
import numpy as np
import random

# m denotes the number of examples here, not the number of features
def gradientDescent(x, y, theta, alpha, m, numIterations):
    xTrans = x.transpose()
    for i in range(0, numIterations):
        hypothesis = np.dot(x, theta)
        loss = hypothesis - y
        # avg cost per example (the 2 in 2*m doesn't really matter here.
        # But to be consistent with the gradient, I include it)
        cost = np.sum(loss ** 2) / (2 * m)
        print("Iteration %d | Cost: %f" % (i, cost))
        # avg gradient per example
        gradient = np.dot(xTrans, loss) / m
        # update
        theta = theta - alpha * gradient
    return theta


def genData(numPoints, bias, variance):
    x = np.zeros(shape=(numPoints, 2))
    y = np.zeros(shape=numPoints)
    # basically a straight line
    for i in range(0, numPoints):
        # bias feature
        x[i][0] = 1
        x[i][1] = i
        # our target variable
        y[i] = (i + bias) + random.uniform(0, 1) * variance
    return x, y

# gen 100 points with a bias of 25 and 10 variance as a bit of noise
x, y = genData(100, 25, 10)
m, n = np.shape(x)
numIterations= 100
alpha = 0.05
theta = np.ones(n)
theta = gradientDescent(x, y, theta, alpha, m, numIterations)
print(theta)
# Out:
# Iteration 0 | Cost: 423.617189
# Iteration 1 | Cost: 8320183.883778
# Iteration 2 | Cost: 221632325792.836090
# Iteration 3 | Cost: 5903899424117807.000000
# Iteration 4 | Cost: 157269605424527998976.000000
# Iteration 5 | Cost: 4189388574159696400744448.000000
# Iteration 6 | Cost: 111598020341714086339104735232.000000
# Iteration 7 | Cost: 2972777035056401310331066380189696.000000
# Iteration 8 | Cost: 79189606348737431408118634891003822080.000000
# Iteration 9 | Cost: 2109473290367038819117023205423900402909184.000000
# Iteration 10 | Cost: 56192697096831648113775950291516665271718772736.000000
# Iteration 11 | Cost: 1496875652057609879477915326431772710457606930432000.000000
# Iteration 12 | Cost: 39874162186267947050117682305480504247799686611255427072.000000
# Iteration 13 | Cost: 1062178283059954250615427437727128658584719181981610191880192.000000
# Iteration 14 | Cost: 28294580829907321074330952979417116243892296888811306118413287424.000000
# Iteration 15 | Cost: 753718389001340843847798771040310648409181370845181380352304348135424.000000
# Iteration 58 | Cost: .000000
# Iteration 59 | Cost: .000000
# Iteration 60 | Cost: .000000
# Iteration 61 | Cost: .000000
# Iteration 62 | Cost: .000000
# Iteration 63 | Cost: .000000
# Iteration 64 | Cost: .000000
# Iteration 65 | Cost: .000000
# Iteration 66 | Cost: .000000
# Iteration 67 | Cost: .000000
# Iteration 68 | Cost: .000000
# Iteration 69 | Cost: inf
# Iteration 70 | Cost: inf
# Iteration 71 | Cost: inf
# Iteration 72 | Cost: inf
# Iteration 73 | Cost: inf
# Iteration 74 | Cost: inf
# Iteration 75 | Cost: inf
# Iteration 76 | Cost: inf
# Iteration 77 | Cost: inf
# Iteration 78 | Cost: inf
# Iteration 79 | Cost: inf
# Iteration 80 | Cost: inf
# Iteration 81 | Cost: inf
# Iteration 82 | Cost: inf
# Iteration 83 | Cost: inf
# Iteration 84 | Cost: inf
# Iteration 85 | Cost: inf
# Iteration 86 | Cost: inf
# Iteration 87 | Cost: inf
# Iteration 88 | Cost: inf
# Iteration 89 | Cost: inf
# Iteration 90 | Cost: inf
# Iteration 91 | Cost: inf
# Iteration 92 | Cost: inf
# Iteration 93 | Cost: inf
# Iteration 94 | Cost: inf
# Iteration 95 | Cost: inf
# Iteration 96 | Cost: inf
# Iteration 97 | Cost: inf
# Iteration 98 | Cost: inf
# Iteration 99 | Cost: inf
# [-1.23923184e+219 -8.21960274e+220]
# /home/orange/venv/lib/python3.6/site-packages/ipykernel_launcher.py:12: RuntimeWarning: overflow encountered in square
#   if sys.path[0] == '':
# /home/orange/venv/lib/python3.6/site-packages/numpy/core/fromnumeric.py:90: RuntimeWarning: overflow encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)

# %%
plt.scatter(x[:,1], y)
plt.plot(x[:,1], np.transpose(np.dot(x, np.transpose(theta))), 'r')
plt.xlabel('x')
plt.ylabel('y')
# Out:
# Text(0, 0.5, 'y')

# %% [markdown]
# # Пример на реальных данных

# %% [markdown]
# Вектора. Загрузим датасет "Hessen House Prices Dataset" из kaggle (https://www.kaggle.com/orgesleka/hessen-house-prices-dataset). 1 вектор в данной таблице - это один дом с различными показателями.

# %%
url="http://yustiks.ru/dataset/houses.json"
df=pd.read_json(url)
df.head()
# Out:
#    posterid           Haustyp Angebotstyp  Wohnflaeche__m²_ Zimmer   abtest  \
# 0  50316225   einfamilienhaus     Angebot               160      6  control
# 1  50379245  mehrfamilienhaus     Angebot               160    8.0  control
# 2  40815451   einfamilienhaus     Angebot               120      4  control
# 3  49513983   einfamilienhaus     Angebot               140      5  control
# 4  49797192   einfamilienhaus     Angebot                80      4  control
#
#      plz  Verkaeufer yo_m  Baujahr  ...  Verfuegbar_ab_Jahr Dachboden  \
# 0  33378  gewerblich    A   1928.0  ...                 NaN       NaN
# 1  65207  gewerblich    A   1968.0  ...                 NaN       NaN
# 2  54647  gewerblich    A   1750.0  ...                 NaN       NaN
# 3   7646  gewerblich    A   2017.0  ...                 NaN       NaN
# 4  54597  gewerblich    A   1900.0  ...                 NaN       NaN
#
#    Verfuegbar_ab_Monat Nebenkosten__in_€_  Kaution__in_€_ Haustiere_erlaubt  \
# 0                  NaN                NaN             NaN               NaN
# 1                  NaN                NaN             NaN               NaN
# 2                  NaN                NaN             NaN               NaN
# 3                  NaN                NaN             NaN               NaN
# 4                  NaN                NaN             NaN               NaN
#
#   Warmmiete__in_€_  Heizkosten__in_€_ WG_geeignet Denkmalobjekt
# 0              NaN                NaN         NaN           NaN
# 1              NaN                NaN         NaN           NaN
# 2              NaN                NaN         NaN           NaN
# 3              NaN                NaN         NaN           NaN
# 4              NaN                NaN         NaN           NaN
#
# [5 rows x 42 columns]

# %% [markdown]
# Три атрибута - год покупки, цена на дом, и метраж (сколько метров представляет собой жил площадь)

# %%
df = df[['Baujahr', 'ExactPreis', 'Wohnflaeche__m²_']]

# %%
df = df.dropna()

# %%
df['bias'] = np.ones(len(df))
x = np.array(df.loc[:500, ['Baujahr', 'Wohnflaeche__m²_', 'bias']])
y = np.array(df.loc[:500, 'ExactPreis'])

# %%
plt.scatter(df['Baujahr'], df['Wohnflaeche__m²_'])

# %%
# m denotes the number of examples here, not the number of features
def gradientDescent(x, y, theta, alpha, m, numIterations):
    xTrans = x.transpose()
    for i in range(0, numIterations):
        hypothesis = np.dot(x, theta)
        loss = hypothesis - y
        cost = np.sum(loss ** 2) / (2 * m)
        print("Iteration %d | Cost: %f" % (i, cost))
        # avg gradient per example
        gradient = np.dot(xTrans, loss) / m
        # update
        theta = theta - alpha * gradient
    return theta

m, n = np.shape(x)
numIterations= 1000
alpha = 0.000005
theta = np.ones(n)
theta = gradientDescent(x, y, theta, alpha, m, numIterations)
print(theta)
# Out:
# Iteration 0 | Cost: 63645814454.143661
# Iteration 1 | Cost: 12142436783569.480469
# Iteration 2 | Cost: 4098459394987823.500000
# Iteration 3 | Cost: 1386519789541598208.000000
# Iteration 4 | Cost: 469066523786878779392.000000
# Iteration 5 | Cost: 158687535356906028662784.000000
# Iteration 6 | Cost: 53684781586705113321308160.000000
# Iteration 7 | Cost: 18161828322121663507819659264.000000
# Iteration 8 | Cost: 6144236751144893351725809795072.000000
# Iteration 9 | Cost: 2078625818092163394664261627150336.000000
# Iteration 10 | Cost: 703209441080573133475957574914277376.000000
# Iteration 11 | Cost: 237899247532066500228469512083997720576.000000
# Iteration 12 | Cost: 80482497347242920660004455624917357953024.000000
# Iteration 13 | Cost: 27227628697631262026106266548288585847537664.000000
# Iteration 14 | Cost: 9211242057978560571057469503935913707540840448.000000
# Iteration 15 | Cost: 3116208950581681136539216139421491445437483188224.000000
# Iteration 16 | Cost: 1054228969618071603976069333852468052802336991477760.000000
# Iteration 17 | Cost: 356650897936264408179568824844807286934839784145682432.000000
# Iteration 18 | Cost: 120656770649004352546207318411777068157056970145212137472.000000
# Iteration 19 | Cost: 40818784945406279333056846324648562980618581168285468852224.000000
# Iteration 20 | Cost: 13809197738818100095106159333729491826544867121079914049044480.000000
# Iteration 21 | Cost: 4671720200511247608342998865763533275655449260108544325315461120.000000
# Iteration 22 | Cost: 1580466153403990395317540269705976170091724688014104644328005566464.000000
# Iteration 23 | Cost: 534679551609756802446409940983613633660721848502941941914749684940800.000000
# Iteration 24 | Cost: 180884748650821117610898497344515993068549934592938144382904521208102912.000000
# Iteration 25 | Cost: 61194209122011408958066139451386439565599557581194240997302725936267919360.000000
# Iteration 26 | Cost: 20702304964899304675242175162831933721810593586758297437005871904137249030144.000000
# Iteration 928 | Cost: nan
# Iteration 929 | Cost: nan
# Iteration 930 | Cost: nan
# Iteration 931 | Cost: nan
# Iteration 932 | Cost: nan
# Iteration 933 | Cost: nan
# Iteration 934 | Cost: nan
# Iteration 935 | Cost: nan
# Iteration 936 | Cost: nan
# Iteration 937 | Cost: nan
# Iteration 938 | Cost: nan
# Iteration 939 | Cost: nan
# Iteration 940 | Cost: nan
# Iteration 941 | Cost: nan
# Iteration 942 | Cost: nan
# Iteration 943 | Cost: nan
# Iteration 944 | Cost: nan
# Iteration 945 | Cost: nan
# Iteration 946 | Cost: nan
# Iteration 947 | Cost: nan
# Iteration 948 | Cost: nan
# Iteration 949 | Cost: nan
# Iteration 950 | Cost: nan
# Iteration 951 | Cost: nan
# Iteration 952 | Cost: nan
# Iteration 953 | Cost: nan
# Iteration 954 | Cost: nan
# Iteration 955 | Cost: nan
# Iteration 956 | Cost: nan
# Iteration 957 | Cost: nan
# Iteration 958 | Cost: nan
# Iteration 959 | Cost: nan
# Iteration 960 | Cost: nan
# Iteration 961 | Cost: nan
# Iteration 962 | Cost: nan
# Iteration 963 | Cost: nan
# Iteration 964 | Cost: nan
# Iteration 965 | Cost: nan
# Iteration 966 | Cost: nan
# Iteration 967 | Cost: nan
# Iteration 968 | Cost: nan
# Iteration 969 | Cost: nan
# Iteration 970 | Cost: nan
# Iteration 971 | Cost: nan
# Iteration 972 | Cost: nan
# Iteration 973 | Cost: nan
# Iteration 974 | Cost: nan
# Iteration 975 | Cost: nan
# Iteration 976 | Cost: nan
# Iteration 977 | Cost: nan
# Iteration 978 | Cost: nan
# Iteration 979 | Cost: nan
# Iteration 980 | Cost: nan
# Iteration 981 | Cost: nan
# Iteration 982 | Cost: nan
# Iteration 983 | Cost: nan
# Iteration 984 | Cost: nan
# Iteration 985 | Cost: nan
# Iteration 986 | Cost: nan
# Iteration 987 | Cost: nan
# Iteration 988 | Cost: nan
# Iteration 989 | Cost: nan
# Iteration 990 | Cost: nan
# Iteration 991 | Cost: nan
# Iteration 992 | Cost: nan
# Iteration 993 | Cost: nan
# Iteration 994 | Cost: nan
# Iteration 995 | Cost: nan
# Iteration 996 | Cost: nan
# Iteration 997 | Cost: nan
# Iteration 998 | Cost: nan
# Iteration 999 | Cost: nan
# [nan nan nan]

# %% [markdown]
# В данном случае невозможно спрогнозировать цену на дом с помощью градиентного спуска

# %% [markdown]
# # Пример функции №2:

# %%
def eggholder(x):
    return (-(x[1] + 47) * np.sin(np.sqrt(abs(x[0]/2 + (x[1]  + 47))))
            -x[0] * np.sin(np.sqrt(abs(x[0] - (x[1]  + 47)))))

bounds = [(-512, 512), (-512, 512)]

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

x = np.arange(-512, 513)
y = np.arange(-512, 513)
xgrid, ygrid = np.meshgrid(x, y)
xy = np.stack([xgrid, ygrid])

fig = plt.figure(figsize=(15,15))
ax = fig.add_subplot(111, projection='3d')
ax.view_init(45, -45)
ax.plot_surface(xgrid, ygrid, eggholder(xy), cmap='terrain')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('eggholder(x, y)')
plt.show()

# %%
t = eggholder(xy)

# %%
len(t)
# Out:
# 1025

# %%
len(t[0])
# Out:
# 1025
